# %%
import pandas as pd
df_h = pd.read_csv('./ObsData/hidrogen_table_ronnyatoche.csv')
print(df_h.head())
print(df_h.shape)
# Out:
#            specObjID         z  fiberMag_r         ew     ewErr
# 0  77910042136805376  0.096130    18.17295   1.202041  0.137201
# 1  77910042229080064  0.039676    18.47620  13.026290  0.198288
# 2  77910042371686400  0.067797    19.06306  13.879700  0.264646
# 3  77910042954694656  0.163473    18.79033  11.662550  0.412270
# 4  77910043105689600  0.083165    19.50517  11.128130  0.319213
# (440288, 5)

# %%
df_n = pd.read_csv('./ObsData/nitrogen_table_ronnyatoche.csv')
print(df_n.head())
print(df_n.shape)
# Out:
#             specObjID         z  fiberMag_r         ew     ewErr
# 0  111968019445448704  0.044624    17.25153   1.872691  0.137486
# 1  111968019911016448  0.068594    18.34439   4.705816  0.187338
# 2  111968019994902528  0.017880    18.99348   1.718214  0.179890
# 3  111968020628242432  0.062302    18.84963  12.000500  0.295785
# 4  111968020787625984  0.061285    18.91270   5.847309  0.249796
# (532019, 5)

# %%
df_h = df_h.rename(columns={'ew':'ew_h'})
df_n = df_n.rename(columns={'ew':'ew_n'})
df_h.head()
# Out:
#            specObjID         z  fiberMag_r       ew_h     ewErr
# 0  77910042136805376  0.096130    18.17295   1.202041  0.137201
# 1  77910042229080064  0.039676    18.47620  13.026290  0.198288
# 2  77910042371686400  0.067797    19.06306  13.879700  0.264646
# 3  77910042954694656  0.163473    18.79033  11.662550  0.412270
# 4  77910043105689600  0.083165    19.50517  11.128130  0.319213

# %%
df_n.head()
# Out:
#             specObjID         z  fiberMag_r       ew_n     ewErr
# 0  111968019445448704  0.044624    17.25153   1.872691  0.137486
# 1  111968019911016448  0.068594    18.34439   4.705816  0.187338
# 2  111968019994902528  0.017880    18.99348   1.718214  0.179890
# 3  111968020628242432  0.062302    18.84963  12.000500  0.295785
# 4  111968020787625984  0.061285    18.91270   5.847309  0.249796

# %%
df_h.dtypes
# Out:
# specObjID       int64
# z             float64
# fiberMag_r    float64
# ew_h          float64
# ewErr         float64
# dtype: object

# %%
result = pd.merge(df_h,df_n, on="specObjID", how="left")
result.head()
# Out:
#            specObjID       z_x  fiberMag_r_x       ew_h   ewErr_x       z_y  \
# 0  77910042136805376  0.096130      18.17295   1.202041  0.137201  0.096130
# 1  77910042229080064  0.039676      18.47620  13.026290  0.198288  0.039676
# 2  77910042371686400  0.067797      19.06306  13.879700  0.264646  0.067797
# 3  77910042954694656  0.163473      18.79033  11.662550  0.412270  0.163473
# 4  77910043105689600  0.083165      19.50517  11.128130  0.319213  0.083165
#
#    fiberMag_r_y       ew_n   ewErr_y
# 0      18.17295   3.691171  0.147553
# 1      18.47620   5.278912  0.155058
# 2      19.06306   4.977230  0.193421
# 3      18.79033  12.802080  0.343948
# 4      19.50517   4.903978  0.289031

# %%
import math 
ope = result["ew_n"] / result["ew_h"]
result["ew_ratio"] = ope
result.head()
# Out:
#            specObjID       z_x  fiberMag_r_x       ew_h   ewErr_x       z_y  \
# 0  77910042136805376  0.096130      18.17295   1.202041  0.137201  0.096130
# 1  77910042229080064  0.039676      18.47620  13.026290  0.198288  0.039676
# 2  77910042371686400  0.067797      19.06306  13.879700  0.264646  0.067797
# 3  77910042954694656  0.163473      18.79033  11.662550  0.412270  0.163473
# 4  77910043105689600  0.083165      19.50517  11.128130  0.319213  0.083165
#
#    fiberMag_r_y       ew_n   ewErr_y  ew_ratio
# 0      18.17295   3.691171  0.147553  3.070753
# 1      18.47620   5.278912  0.155058  0.405251
# 2      19.06306   4.977230  0.193421  0.358598
# 3      18.79033  12.802080  0.343948  1.097708
# 4      19.50517   4.903978  0.289031  0.440683

# %%
def ox_ab(x):
    return 8.9 + 0.57*math.log( x ,10)
result["ox_abund"] = result[["ew_ratio"]].apply(ox_ab, axis=1)
result.head()
# Out:
#            specObjID       z_x  fiberMag_r_x       ew_h   ewErr_x       z_y  \
# 0  77910042136805376  0.096130      18.17295   1.202041  0.137201  0.096130
# 1  77910042229080064  0.039676      18.47620  13.026290  0.198288  0.039676
# 2  77910042371686400  0.067797      19.06306  13.879700  0.264646  0.067797
# 3  77910042954694656  0.163473      18.79033  11.662550  0.412270  0.163473
# 4  77910043105689600  0.083165      19.50517  11.128130  0.319213  0.083165
#
#    fiberMag_r_y       ew_n   ewErr_y  ew_ratio  ox_abund
# 0      18.17295   3.691171  0.147553  3.070753  9.177730
# 1      18.47620   5.278912  0.155058  0.405251  8.676402
# 2      19.06306   4.977230  0.193421  0.358598  8.646126
# 3      18.79033  12.802080  0.343948  1.097708  8.923078
# 4      19.50517   4.903978  0.289031  0.440683  8.697152

# %%
result = result.drop(["fiberMag_r_y", "ewErr_y", "z_y", "ewErr_x"],axis=1)
result.head()
# Out:
#            specObjID       z_x  fiberMag_r_x       ew_h       ew_n  ew_ratio  \
# 0  77910042136805376  0.096130      18.17295   1.202041   3.691171  3.070753
# 1  77910042229080064  0.039676      18.47620  13.026290   5.278912  0.405251
# 2  77910042371686400  0.067797      19.06306  13.879700   4.977230  0.358598
# 3  77910042954694656  0.163473      18.79033  11.662550  12.802080  1.097708
# 4  77910043105689600  0.083165      19.50517  11.128130   4.903978  0.440683
#
#    ox_abund
# 0  9.177730
# 1  8.676402
# 2  8.646126
# 3  8.923078
# 4  8.697152

# %%
result = result.rename(columns = {'z_x':'z', 'fiberMag_r_x':'fiberMag_r'})
result.head()
# Out:
#            specObjID         z  fiberMag_r       ew_h       ew_n  ew_ratio  \
# 0  77910042136805376  0.096130    18.17295   1.202041   3.691171  3.070753
# 1  77910042229080064  0.039676    18.47620  13.026290   5.278912  0.405251
# 2  77910042371686400  0.067797    19.06306  13.879700   4.977230  0.358598
# 3  77910042954694656  0.163473    18.79033  11.662550  12.802080  1.097708
# 4  77910043105689600  0.083165    19.50517  11.128130   4.903978  0.440683
#
#    ox_abund
# 0  9.177730
# 1  8.676402
# 2  8.646126
# 3  8.923078
# 4  8.697152

# %%
result.shape
# Out:
# (440288, 7)

# %%
from astropy import cosmology
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)
cosmo.luminosity_distance(4).value
# Out:
# 35851.83207231648

# %%
def dz(x):
    return cosmo.luminosity_distance(x).value
result["dz"] = result[["z"]].apply(dz, axis=1)
result.head()
# Out:
#            specObjID         z  fiberMag_r       ew_h       ew_n  ew_ratio  \
# 0  77910042136805376  0.096130    18.17295   1.202041   3.691171  3.070753
# 1  77910042229080064  0.039676    18.47620  13.026290   5.278912  0.405251
# 2  77910042371686400  0.067797    19.06306  13.879700   4.977230  0.358598
# 3  77910042954694656  0.163473    18.79033  11.662550  12.802080  1.097708
# 4  77910043105689600  0.083165    19.50517  11.128130   4.903978  0.440683
#
#    ox_abund               dz
# 0  9.177730  [441.338306149]
# 1  8.676402  [175.075998092]
# 2  8.646126  [305.251863115]
# 3  8.923078  [783.744189444]
# 4  8.697152  [378.457781847]

# %%
result.dtypes
# Out:
# specObjID       int64
# z             float64
# fiberMag_r    float64
# ew_h          float64
# ew_n          float64
# ew_ratio      float64
# ox_abund      float64
# dz             object
# dtype: object

# %%
result['dz'] = result['dz'].astype(str)
result.dtypes
# Out:
# specObjID       int64
# z             float64
# fiberMag_r    float64
# ew_h          float64
# ew_n          float64
# ew_ratio      float64
# ox_abund      float64
# dz             object
# dtype: object

# %%
result['dz'] = [float(str(val).replace(' ','').replace('[','').replace(']','')) for val in result['dz'].values]
result.head()
# Out:
#            specObjID         z  fiberMag_r       ew_h       ew_n  ew_ratio  \
# 0  77910042136805376  0.096130    18.17295   1.202041   3.691171  3.070753
# 1  77910042229080064  0.039676    18.47620  13.026290   5.278912  0.405251
# 2  77910042371686400  0.067797    19.06306  13.879700   4.977230  0.358598
# 3  77910042954694656  0.163473    18.79033  11.662550  12.802080  1.097708
# 4  77910043105689600  0.083165    19.50517  11.128130   4.903978  0.440683
#
#    ox_abund          dz
# 0  9.177730  441.338306
# 1  8.676402  175.075998
# 2  8.646126  305.251863
# 3  8.923078  783.744189
# 4  8.697152  378.457782

# %%
result.dtypes
# Out:
# specObjID       int64
# z             float64
# fiberMag_r    float64
# ew_h          float64
# ew_n          float64
# ew_ratio      float64
# ox_abund      float64
# dz            float64
# dtype: object

# %%
result['fiberMag_r'][1]
# Out:
# 18.476199999999999

# %%
result.shape
# Out:
# (440288, 8)

# %%
result = result[result['dz']>0]
result.shape
# Out:
# (439905, 8)

# %%
def log_dz(x):
    return math.log( x ,10)
result["log_dz"] = result[["dz"]].apply(log_dz, axis=1)
result.head()
# Out:
#            specObjID         z  fiberMag_r       ew_h       ew_n  ew_ratio  \
# 0  77910042136805376  0.096130    18.17295   1.202041   3.691171  3.070753
# 1  77910042229080064  0.039676    18.47620  13.026290   5.278912  0.405251
# 2  77910042371686400  0.067797    19.06306  13.879700   4.977230  0.358598
# 3  77910042954694656  0.163473    18.79033  11.662550  12.802080  1.097708
# 4  77910043105689600  0.083165    19.50517  11.128130   4.903978  0.440683
#
#    ox_abund          dz    log_dz
# 0  9.177730  441.338306  2.644772
# 1  8.676402  175.075998  2.243227
# 2  8.646126  305.251863  2.484658
# 3  8.923078  783.744189  2.894174
# 4  8.697152  378.457782  2.578017

# %%
result.reset_index()
result.head()
# Out:
#            specObjID         z  fiberMag_r       ew_h       ew_n  ew_ratio  \
# 0  77910042136805376  0.096130    18.17295   1.202041   3.691171  3.070753
# 1  77910042229080064  0.039676    18.47620  13.026290   5.278912  0.405251
# 2  77910042371686400  0.067797    19.06306  13.879700   4.977230  0.358598
# 3  77910042954694656  0.163473    18.79033  11.662550  12.802080  1.097708
# 4  77910043105689600  0.083165    19.50517  11.128130   4.903978  0.440683
#
#    ox_abund          dz    log_dz
# 0  9.177730  441.338306  2.644772
# 1  8.676402  175.075998  2.243227
# 2  8.646126  305.251863  2.484658
# 3  8.923078  783.744189  2.894174
# 4  8.697152  378.457782  2.578017

# %%
result['ab_mag_r'] = (result['fiberMag_r'])-25-5*(result['log_dz'])
result.head()
# Out:
#            specObjID         z  fiberMag_r       ew_h       ew_n  ew_ratio  \
# 0  77910042136805376  0.096130    18.17295   1.202041   3.691171  3.070753
# 1  77910042229080064  0.039676    18.47620  13.026290   5.278912  0.405251
# 2  77910042371686400  0.067797    19.06306  13.879700   4.977230  0.358598
# 3  77910042954694656  0.163473    18.79033  11.662550  12.802080  1.097708
# 4  77910043105689600  0.083165    19.50517  11.128130   4.903978  0.440683
#
#    ox_abund          dz    log_dz   ab_mag_r
# 0  9.177730  441.338306  2.644772 -20.050908
# 1  8.676402  175.075998  2.243227 -17.739933
# 2  8.646126  305.251863  2.484658 -18.360232
# 3  8.923078  783.744189  2.894174 -20.680542
# 4  8.697152  378.457782  2.578017 -18.384917

# %%
result.dtypes
# Out:
# specObjID       int64
# z             float64
# fiberMag_r    float64
# ew_h          float64
# ew_n          float64
# ew_ratio      float64
# ox_abund      float64
# dz            float64
# log_dz        float64
# ab_mag_r      float64
# dtype: object

# %%
result.shape
# Out:
# (439905, 10)

# %%
result.describe()
# Out:
#           specObjID             z     fiberMag_r           ew_h  \
# count  4.399050e+05  4.399050e+05  438495.000000  439905.000000
# mean   3.989691e+17  9.958512e-02      17.773706      20.127027
# std    2.046874e+17  5.854048e-02     102.602479      37.343565
# min    7.509397e+16  2.768460e-07   -9999.000000       0.043715
# 25%    2.223086e+17  6.004580e-02      18.442490       6.410007
# 50%    3.900709e+17  9.007770e-02      18.840260      13.926530
# 75%    5.626165e+17  1.307370e-01      19.223140      25.465430
# max    8.373411e+17  4.884630e+00      23.644540   10000.000000
#
#                 ew_n       ew_ratio       ox_abund             dz  \
# count  425972.000000  425972.000000  425972.000000  439905.000000
# mean        7.715124       0.633890       8.727807     467.776307
# std         7.684810       0.568104       0.165627     319.579289
# min         0.330860       0.002125       7.376546       0.001186
# 25%         3.818233       0.356576       8.644727     268.875086
# 50%         6.035045       0.460764       8.708183     411.858580
# 75%         9.624474       0.701002       8.812060     614.044912
# max      2686.413000      56.716541       9.899615   45390.706617
#
#               log_dz       ab_mag_r
# count  439905.000000  438495.000000
# mean        2.580854     -20.135617
# std         0.310074     102.603206
# min        -2.926040  -10039.153572
# 25%         2.429551     -20.138573
# 50%         2.614748     -19.383289
# 75%         2.788200     -18.379281
# max         4.656967       8.462747

# %%
# 425712  0.471917  8.714103   421.498938  2.624796           NaN
# 425713  0.533241  8.744346  1099.723129  3.041283           NaN
# 425723  1.969053  9.067727   433.816430  2.637306           NaN
# 427022  0.485625  8.721191   393.351050  2.594780           NaN
# 427706  0.380142  8.660569   434.282441  2.637772           NaN
# 427714  0.420844  8.685749   439.262160  2.642724           NaN
# 427807  0.472153  8.714227   213.261643  2.328913           NaN
# 428469  0.439542  8.696510   294.732477  2.469428           NaN
# 428475  0.687854  8.807373   517.693366  2.714073           NaN
# 428477  1.984800  9.069699   972.717379  2.987987           NaN
# 428478  0.463705  8.709758   541.099802  2.733277           NaN
# 428479  0.708601  8.814729   922.306833  2.964875           NaN
# 428481  1.463066  8.994201   297.763384  2.473871           NaN
# 428485  0.341881  8.634309   143.566665  2.157054           NaN
# 428487  0.425564  8.688510   336.966639  2.527587           NaN
# 428490  0.599558  8.773364   140.229641  2.146840           NaN
# 428494  0.337345  8.631002   327.865200  2.515695           NaN
# 428501  0.446589  8.700448   190.918055  2.280847           NaN
# 430197  0.090369  8.304930    79.893914  1.902514           NaN
# 430587  0.187525  8.485643    97.495020  1.988982           NaN
# 430607  0.095479  8.318547   111.741000  2.048213           NaN
# 431771       NaN       NaN     4.903679  0.690522           NaN
# 432176  0.418324  8.684262   298.980325  2.475643           NaN
# 432179  2.782170  9.153299   290.081490  2.462520           NaN
# 432180  0.331101  8.626378   292.921369  2.466751           NaN
# 432183  0.467295  8.711667   340.261474  2.531813           NaN
# 432186       NaN       NaN   809.903672  2.908433           NaN
# 432192  1.927244  9.062414   411.040559  2.613885           NaN
#
# [439905 rows x 10 columns]

# %%
count_NaN = result.isna().sum()
print(count_NaN)
# Out:
# specObjID         0
# z                 0
# fiberMag_r     1410
# ew_h              0
# ew_n          13933
# ew_ratio      13933
# ox_abund      13933
# dz                0
# log_dz            0
# ab_mag_r       1410
# dtype: int64

# %%
result.dropna()
# Out:
#                  specObjID         z  fiberMag_r       ew_h       ew_n  \
# 0        77910042136805376  0.096130    18.17295   1.202041   3.691171
# 1        77910042229080064  0.039676    18.47620  13.026290   5.278912
# 2        77910042371686400  0.067797    19.06306  13.879700   4.977230
# 3        77910042954694656  0.163473    18.79033  11.662550  12.802080
# 4        77910043105689600  0.083165    19.50517  11.128130   4.903978
# 5        77910043478982656  0.118737    18.87039   6.774915   4.502785
# 6        77910043571257344  0.147087    18.64308  23.136280   8.940736
# 7        77910043629977600  0.103283    19.06304  28.482300   9.845634
# 8        77910043655143424  0.084613    19.43973   6.086303   3.205124
# 9        78191511828692992  0.112670    18.23006  10.800580   8.592798
# 10       78191512470421504  0.064722    18.77041  30.092170  23.459470
# 11       78191512705302528  0.150675    18.40637   5.238653   3.401809
# 12       78191513170870272  0.094986    19.99205  14.323200   4.724965
# 13       78191513196036096  0.148934    19.11210  16.042580   6.954963
# 14       78191513347031040  0.084778    18.70187   9.112389   4.333262
# 15       78191513812598784  0.184692    18.70121   3.260710   3.116664
# 16       78191513837764608  0.095487    17.62722   1.021922   2.523127
# 440281  0.371864  8.655119   353.889701  2.548868 -19.074570
# 440282  0.451764  8.703300   432.334827  2.635820 -19.276821
# 440283  1.040914  8.909926   523.638899  2.719032 -19.987770
# 440284  1.081255  8.919339   457.858589  2.660731 -19.956577
# 440285  0.388619  8.666029   215.924658  2.334302 -17.776191
# 440286  0.673403  8.802117   439.780118  2.643236 -19.477658
# 440287  0.560523  8.756698   537.926156  2.730723 -20.313253
#
# [424671 rows x 10 columns]

# %%
result.describe()
# Out:
#           specObjID             z     fiberMag_r           ew_h  \
# count  4.399050e+05  4.399050e+05  438495.000000  439905.000000
# mean   3.989691e+17  9.958512e-02      17.773706      20.127027
# std    2.046874e+17  5.854048e-02     102.602479      37.343565
# min    7.509397e+16  2.768460e-07   -9999.000000       0.043715
# 25%    2.223086e+17  6.004580e-02      18.442490       6.410007
# 50%    3.900709e+17  9.007770e-02      18.840260      13.926530
# 75%    5.626165e+17  1.307370e-01      19.223140      25.465430
# max    8.373411e+17  4.884630e+00      23.644540   10000.000000
#
#                 ew_n       ew_ratio       ox_abund             dz  \
# count  425972.000000  425972.000000  425972.000000  439905.000000
# mean        7.715124       0.633890       8.727807     467.776307
# std         7.684810       0.568104       0.165627     319.579289
# min         0.330860       0.002125       7.376546       0.001186
# 25%         3.818233       0.356576       8.644727     268.875086
# 50%         6.035045       0.460764       8.708183     411.858580
# 75%         9.624474       0.701002       8.812060     614.044912
# max      2686.413000      56.716541       9.899615   45390.706617
#
#               log_dz       ab_mag_r
# count  439905.000000  438495.000000
# mean        2.580854     -20.135617
# std         0.310074     102.603206
# min        -2.926040  -10039.153572
# 25%         2.429551     -20.138573
# 50%         2.614748     -19.383289
# 75%         2.788200     -18.379281
# max         4.656967       8.462747

# %%
import matplotlib.pyplot as plt
plt.scatter(result["ab_mag_r"],result["ox_abund"])
plt.show()

# %%
result_loc = result.loc[result['ab_mag_r'] > -200]
result_loc.describe()
# Out:
#           specObjID             z     fiberMag_r           ew_h  \
# count  4.384490e+05  4.384490e+05  438449.000000  438449.000000
# mean   3.994100e+17  9.970009e-02      18.824619      20.100435
# std    2.047228e+17  5.852491e-02       0.700521      37.335162
# min    7.509397e+16  2.768460e-07      14.782850       0.043715
# 25%    2.225904e+17  6.017880e-02      18.442650       6.403709
# 50%    3.906339e+17  9.018720e-02      18.840320      13.914360
# 75%    5.631797e+17  1.308240e-01      19.223190      25.441910
# max    8.373411e+17  4.884630e+00      23.644540   10000.000000
#
#                 ew_n       ew_ratio       ox_abund             dz  \
# count  424633.000000  424633.000000  424633.000000  438449.000000
# mean        7.712712       0.634238       8.728010     468.332458
# std         7.681052       0.568107       0.165507     319.621683
# min         0.330860       0.002125       7.376546       0.001186
# 25%         3.818153       0.356809       8.644889     269.496080
# 50%         6.034258       0.460988       8.708303     412.389950
# 75%         9.621136       0.701482       8.812230     614.487865
# max      2686.413000      56.716541       9.899615   45390.706617
#
#               log_dz       ab_mag_r
# count  438449.000000  438449.000000
# mean        2.581882     -19.084792
# std         0.308763       1.548878
# min        -2.926040     -30.938940
# 25%         2.430552     -20.138325
# 50%         2.615308     -19.383130
# 75%         2.788513     -18.379163
# max         4.656967       8.462747

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
font = {'family' : 'normal',
        'size'   : 18}
plt.rc('font', **font)
figure(figsize=(12, 8))

plt.scatter(result_loc["ab_mag_r"],result_loc["ox_abund"], s=0.1)
plt.gca().invert_xaxis()

plt.xlim(-5, -25 )
plt.ylim(7.5, 9.5)
plt.xlabel(r'Absolute Magnitude r')
plt.ylabel(r'$12+log(\frac{O}{H})$')
plt.title('Observed Oxygen Abundance')
#plt.legend()
plt.show()
# Out:
# /Software/users/modules/7/software/anaconda3/4.2.0/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
font = {'family' : 'normal',
        'size'   : 18}
plt.rc('font', **font)
figure(figsize=(12, 8))

plt.scatter(result_loc["ab_mag_r"],result_loc["ox_abund"], s=0.1)
plt.gca().invert_xaxis()


plt.xlim(-5, -25 )
plt.ylim(7.5, 9.5)
plt.xlabel(r'Absolute Magnitude r')
plt.ylabel(r'$12+log(\frac{O}{H})$')
plt.title('Observed Oxygen Abundance')
#plt.legend()
plt.show()
# Out:
# /Software/users/modules/7/software/anaconda3/4.2.0/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# nan
# nan

# %%
result_loc.dtypes
# Out:
# specObjID       int64
# z             float64
# fiberMag_r    float64
# ew_h          float64
# ew_n          float64
# ew_ratio      float64
# ox_abund      float64
# dz            float64
# log_dz        float64
# ab_mag_r      float64
# dtype: object

# %%
import numpy as np
import numpy

x = result_loc['ab_mag_r'].values.tolist()
y = result_loc['ox_abund'].values.tolist()

x = numpy.array(x)
y = numpy.array(y)

m, b = np.polyfit(x,y,1)
print(m)
print(b)
# Out:
# nan
# nan

# %%
result_loc.isna().sum()
# Out:
# specObjID         0
# z                 0
# fiberMag_r        0
# ew_h              0
# ew_n          13816
# ew_ratio      13816
# ox_abund      13816
# dz                0
# log_dz            0
# ab_mag_r          0
# dtype: int64

# %%
c_result = result_loc.dropna()

# %%
clean_result.isna().sum()
# Out:
# specObjID     0
# z             0
# fiberMag_r    0
# ew_h          0
# ew_n          0
# ew_ratio      0
# ox_abund      0
# dz            0
# log_dz        0
# ab_mag_r      0
# dtype: int64

# %%
import numpy as np
import numpy

x = c_result['ab_mag_r'].values.tolist()
y = c_result['ox_abund'].values.tolist()

x = numpy.array(x)
y = numpy.array(y)

m, b = np.polyfit(x,y,1)
print(m)
print(b)
# Out:
# -0.063481223789
# 7.51311846483

# %%
y.shape
# Out:
# (424633,)

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
font = {'family' : 'normal',
        'size'   : 18}
plt.rc('font', **font)
figure(figsize=(12, 8))

plt.scatter(result_loc["ab_mag_r"],result_loc["ox_abund"], s=0.1)
plt.gca().invert_xaxis()

plt.plot(x, m*x + b, color="red")
plt.xlim(-5, -25 )
plt.ylim(7.5, 9.5)
plt.xlabel(r'Absolute Magnitude r')
plt.ylabel(r'$12+log(\frac{O}{H})$')
plt.title('Observed Oxygen Abundance')
#plt.legend()
plt.show()
print("y=", m, "*x+", b)
# Out:
# /Software/users/modules/7/software/anaconda3/4.2.0/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# y= -0.063481223789 *x+ 7.51311846483
